# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\A plus\\Desktop\\1.B.tech\\5th Semester\\Data Science\\DS AI ML\\Log_reg.csv")

# %%
df
# Out:
#    Age Bought_insurance
# 0   21               No
# 1   48              Yes
# 2   32              Yes
# 3   41              Yes
# 4   20               No
# 5   35              Yes
# 6   20               No
# 7   23               No

# %%
df['Bought_insurance'].replace({'No':'0', 'Yes': '1'}, inplace=True)
df
# Out:
#    Age  Bought_insurance
# 0   21                 0
# 1   48                 1
# 2   32                 1
# 3   41                 1
# 4   20                 0
# 5   35                 1
# 6   20                 0
# 7   23                 0

# %%
plt.scatter(x='Age', y='Bought_insurance', data=df)

# %%
print(df.columns)
# Out:
# Index(['Age', 'Bought_insurance'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(df[['Age']], df[['Bought_insurance']], test_size=0.2)

# %%
len(x_train)
# Out:
# 6

# %%
len(x_test)
# Out:
# 2

# %%
x_train
# Out:
#    Age
# 4   20
# 0   21
# 2   32
# 3   41
# 1   48
# 6   20

# %%
x_test
# Out:
#    Age
# 5   35
# 7   23

# %%
y_train
# Out:
#    Bought_insurance
# 4                 0
# 3                 1
# 1                 1
# 6                 0
# 7                 0
# 0                 0

# %%
y_test
# Out:
#    Bought_insurance
# 2                 1
# 5                 1

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\A plus\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array([0, 1])

# %%
lr.predict([[23]])
# Out:
# C:\Users\A plus\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
