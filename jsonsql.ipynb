# %% [markdown]
# ### Working With Json

# %%
# importing pandas for data manipulation and Analysis
import pandas as pd

# %%
# made a dataframe and read json file from the path of json file named 'test.json'
df = pd.read_json("C:\\Users\\A plus\\Desktop\\1.B.tech\\5th Semester\\Data Science\\DS AI ML\\test.json\\test.json")
df
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %%
'''gathered information about file
and it contains 99449 entries or rows with two columns
id and ingrediend , datatype is int and obj resp.
there are no null from the entries it means that there is no missing or null presemt in the data
'''
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9944 non-null   int64
#  1   ingredients  9944 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 155.5+ KB

# %%
# this print the top 5 entries of the data 
df.head()
# Out:
#       id                                        ingredients
# 0  18009  [baking powder, eggs, all-purpose flour, raisi...
# 1  28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2  41580  [sausage links, fennel bulb, fronds, olive oil...
# 3  29752  [meat cuts, file powder, smoked sausage, okra,...
# 4  35687  [ground black pepper, salt, sausage casings, l...

# %%
# this prints the last 5 entries of the data
df.tail()
# Out:
#          id                                        ingredients
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...

# %%
pd.read_sql("C:\\Users\\A plus\\Downloads\\world.sql")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pd.read_sql("C:\\Users\\A plus\\Downloads\\world.sql")
#
# TypeError: read_sql() missing 1 required positional argument: 'con'

# %%
# installing mysql.coonector to communicate the pytohn with mysql
# !pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/11.9 MB 1.9 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.3/11.9 MB 1.9 MB/s eta 0:00:06
#      ------ --------------------------------- 1.8/11.9 MB 2.2 MB/s eta 0:00:05
#      ------- -------------------------------- 2.1/11.9 MB 2.4 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/11.9 MB 2.2 MB/s eta 0:00:05
#      ----------- ---------------------------- 3.4/11.9 MB 2.4 MB/s eta 0:00:04
#      ------------- -------------------------- 3.9/11.9 MB 2.4 MB/s eta 0:00:04
# ...

# %%
# import mysql.connector
import mysql.connector

# %%
# Making connection to the database
mydbconn = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password='',
    database= 'world',
    port =3306
)

# %%
# to read sql file we have to give query and our connection object of the database
query = 'SELECT * FROM city'
pd.read_sql_query(query,mydbconn)
# Out:
# C:\Users\A plus\AppData\Local\Temp\ipykernel_2676\2218828769.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(query,mydbconn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

# %%
quer = 'SELECT * FROM country'
pd.read_sql_query(quer, mydbconn)
# Out:
# C:\Users\A plus\AppData\Local\Temp\ipykernel_2676\804584060.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(quer, mydbconn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
que = 'SELECT * FROM countrylanguage'
pd.read_sql_query(que, mydbconn)
# Out:
# C:\Users\A plus\AppData\Local\Temp\ipykernel_2676\603369371.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(que, mydbconn)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
