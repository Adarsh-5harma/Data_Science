# %%
# data
import pandas as pd
# Visualization
import seaborn as sns
# Numerical
import numpy as np
# visualization
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("C:\\Users\\A plus\\Desktop\\1.B.tech\\5th Semester\\Data Science\\DS AI ML\\regression.csv")
df
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='Age' ,y='Premium',data=df)

# %%
regs =linear_model.LinearRegression()

# %%
regs.fit(df[['Age']], df[['Premium']])
# Out:
# LinearRegression()

# %%
regs.predict([[26]])
# Out:
# C:\Users\A plus\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[22780.]])

# %%
regs.predict([[51]])
# Out:
# C:\Users\A plus\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[67280.]])

# %%
regs.predict([[21]])
# Out:
# C:\Users\A plus\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13880.]])

# %%
# Slope
regs.coef_
# Out:
# array([[1780.]])

# %%
regs.intercept_
# Out:
# array([-23500.])
